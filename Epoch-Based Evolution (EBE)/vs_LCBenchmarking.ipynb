# %%
from api import Benchmark

# %%
import os
os.listdir()
# Out:
# ['api.py',
#  'EBE-NAS_LCBench_results.csv',
#  'EBE_benchmarking LCBench.py',
#  'EBE_benchmarking.py',
#  'ebe_results.py',
#  'ebe_six_datasets.ipynb',
#  'EBE_testing CIFAR.ipynb',
#  'EBE_testing.ipynb',
#  'EBE_thoughts.md',
#  'epoch_based_evolution.py',
#  'load_data.py',
#  'models_ES_training_results.csv',
#  'process_log.txt',
#  'random_search_results.csv',
#  'random_search_test.py',
#  'six_datasets_lw',
#  'vs_LCBenchmarking.ipynb',
#  '__pycache__']

# %%
bench_dir = "./six_datasets_lw/six_datasets_lw.json"
bench = Benchmark(bench_dir, cache=False)
# Out:
# ==> Loading data...
# ==> No cached data found or cache set to False.
# ==> Reading json data...
# ==> Done.

# %%
dataset_names = bench.get_dataset_names()
openml_task_ids = bench.get_openml_task_ids()

print(dataset_names)
print(openml_task_ids)
# Out:
# ['Fashion-MNIST', 'adult', 'higgs', 'jasmine', 'vehicle', 'volkert']
# [189908, 126025, 167200, 189862, 167168, 168331]

# %%
# Get an example for a loss log
example_loss = bench.query(dataset_name="higgs", tag="Train/loss", config_id=0)

# Get the log of the accuracy for the run with the best peak accuracy
example_best_acc = bench.query_best("higgs", "Train/val_accuracy", "Train/val_accuracy", 0)

# Get the configuration of the best performing configuration
example_best_config = bench.query_best("higgs", "config", "Train/val_accuracy", 1)

print("Example loss log:\n", example_loss)
print("Best validation accuracy log:\n", example_best_acc)
print("Best config with regard to validation accuracy:\n", example_best_config)
# Out:
# Example loss log:
#  [0.7022241950035095, 0.6901828646659851, 0.6828941702842712, 0.6783701181411743, 0.674620509147644, 0.6713433265686035, 0.6683977246284485, 0.6656985878944397, 0.6632551550865173, 0.6610167622566223, 0.6589627861976624, 0.6570730805397034, 0.6553987860679626, 0.6539356708526611, 0.6525501608848572, 0.6513078808784485, 0.650172233581543, 0.6491538882255554, 0.648234486579895, 0.6474276185035706, 0.6466533541679382, 0.6459929347038269, 0.6453624367713928, 0.6447970271110535, 0.6442720890045166, 0.6438338160514832, 0.6434042453765869, 0.6430007815361023, 0.6426441669464111, 0.6423296928405762, 0.6420345306396484, 0.6417556405067444, 0.6414902806282043, 0.6412926912307739, 0.6411048173904419, 0.6409232020378113, 0.6407663822174072, 0.6406413316726685, 0.6405110359191895, 0.640395998954773, 0.6403017640113831, 0.6402287483215332, 0.6401697993278503, 0.6400859951972961, 0.6400653719902039, 0.6400305032730103, 0.6400076746940613, 0.6399728059768677, 0.6399630904197693, 0.6399649381637573, 0.6399642825126648, 0.6399548649787903]
# Best validation accuracy log:
#  [51.19464874267578, 63.48247146606445, 65.89944458007811, 66.47601318359375, 67.42158508300781, 67.94741821289061, 68.64391326904297, 68.69464874267578, 69.01291656494139, 69.48800659179689, 69.89852142333984, 70.0645751953125, 70.07379913330078, 69.85700988769531, 70.48892974853516, 70.49354553222656, 70.7333984375, 70.91790008544922, 70.95479583740234, 71.1900405883789, 71.28690338134766, 71.30535125732422, 71.47601318359375, 71.15313720703125, 71.48062896728516, 71.30535125732422, 71.5728759765625, 71.5728759765625, 71.34686279296875, 71.47601318359375, 71.41143798828125, 71.71586608886719, 71.79889678955078, 71.7666015625, 71.75276947021484, 71.69741821289062, 71.8357925415039, 71.8357925415039, 71.67435455322266, 71.74354553222656, 71.7666015625, 71.88652801513672, 71.80812072753906, 71.8496322631836, 71.7204818725586, 71.85885620117188, 71.82656860351562, 71.79428100585938, 71.80350494384766, 71.82195281982422, 71.83118438720703, 71.82656860351562]
# Best config with regard to validation accuracy:
#  {'batch_size': 124, 'imputation_strategy': 'mean', 'learning_rate_scheduler': 'cosine_annealing', 'loss': 'cross_entropy_weighted', 'network': 'shapedmlpnet', 'max_dropout': 0.00910225473215609, 'normalization_strategy': 'standardize', 'optimizer': 'sgd', 'cosine_annealing_T_max': 50, 'cosine_annealing_eta_min': 1e-08, 'activation': 'relu', 'max_units': 106, 'mlp_shape': 'funnel', 'num_layers': 3, 'learning_rate': 0.07113964491331314, 'momentum': 0.46269226264944247, 'weight_decay': 0.0018436505744833952}

# %%
bench.plot_by_name(dataset_names=['Fashion-MNIST', 'adult', 'higgs', 'jasmine', 'vehicle', 'volkert'],
                   x_col="epoch",
                   y_col="Train/val_accuracy",
                   n_configs=10,
                   xscale='linear',
                   yscale='linear',
                   show_best=False)

# %%
max(example_best_acc)
# Out:
# 71.88652801513672
